# %%
#!/usr/bin/env python3
# modified based on this code: https://github.com/theRealSuperMario/supermariopy/blob/master/scripts/tflogs2pandas.py
"""This is a enhanced version of
https://gist.github.com/ptschandl/ef67bbaa93ec67aba2cab0a7af47700b

This script exctracts variables from all logs from tensorflow event
files ("event*"),
writes them to Pandas and finally stores them a csv-file or
pickle-file including all (readable) runs of the logging directory.

Example usage:

# create csv file from all tensorflow logs in provided directory (.)
# and write it to folder "./converted"
tflogs2pandas.py . --write-csv --no-write-pkl --o converted

# creaste csv file from tensorflow logfile only and write into
# and write it to folder "./converted"
tflogs2pandas.py tflog.hostname.12345 --write-csv --no-write-pkl --o converted
"""
import glob
import os
import pprint
import traceback

import click
import pandas as pd
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
from pathlib import Path

import numpy as np

import matplotlib.pyplot as plt
import pickle

# %%
# Extraction function
def tflog2pandas(path: str) -> pd.DataFrame:
    """convert single tensorflow log file to pandas DataFrame

    Parameters
    ----------
    path : str
        path to tensorflow log file

    Returns
    -------
    pd.DataFrame
        converted dataframe
    """
    DEFAULT_SIZE_GUIDANCE = {
        "compressedHistograms": 1,
        "images": 1,
        "scalars": 0,  # 0 means load all
        "histograms": 1,
    }
    runlog_data = pd.DataFrame({"metric": [], "value": [], "step": []})
    try:
        event_acc = EventAccumulator(path, DEFAULT_SIZE_GUIDANCE)
        event_acc.Reload()
        tags = event_acc.Tags()["scalars"]
        for tag in tags:
            event_list = event_acc.Scalars(tag)
            values = list(map(lambda x: x.value, event_list))
            step = list(map(lambda x: x.step, event_list))
            r = {"metric": [tag] * len(step), "value": values, "step": step}
            r = pd.DataFrame(r)
            runlog_data = pd.concat([runlog_data, r])
    # Dirty catch of DataLossError
    except Exception:
        print("Event file possibly corrupt: {}".format(path))
        traceback.print_exc()
    return runlog_data


def many_logs2pandas(event_paths):
    all_logs = pd.DataFrame()
    for path in event_paths:
        log = tflog2pandas(path)
        if log is not None:
            if all_logs.shape[0] == 0:
                all_logs = log
            else:
                all_logs = all_logs.append(log, ignore_index=True)
    return all_logs

# %%
def segment_df(df):
    imitation_rew = []
    real_rew = []
    critic_loss = []
    bc_loss = []
    actor_loss = []
    
    for itm in df:
        if 'rollout/ep_rew_mean' in itm:
            real_rew.append(itm)
        elif 'rollout/ep_imitation_mean' in itm:
            imitation_rew.append(itm)
        elif 'train/bc_loss' in itm:
            bc_loss.append(itm)
        elif 'train/actor_critic_loss' in itm:
            actor_loss.append(itm)
        elif 'train/critic_loss' in itm:
            critic_loss.append(itm)
            
    return imitation_rew, real_rew, critic_loss, bc_loss, actor_loss

# %%
def parse_data_from_boards(logdir_or_logfile):
    #logdir_or_logfile = "tmp/pwil/constrained_by_none/HalfCheetahBulletEnv-v0_subsampling_20_numdemo_5_random_0/20210218173556/events.out.tfevents.1613662564.users-MBP.82461.0"
    write_pkl = False
    write_csv = False
    out_dir = None

    pp = pprint.PrettyPrinter(indent=4)

    if os.path.isdir(logdir_or_logfile):
        # Get all event* runs from logging_dir subdirectories
        event_paths = glob.glob(os.path.join(logdir_or_logfile, "event*"))
    elif os.path.isfile(logdir_or_logfile):
        event_paths = [logdir_or_logfile]
    else:
        raise ValueError(
            "input argument {} has to be a file or a directory".format(
                logdir_or_logfile
            )
        )
    # Call & append
    if event_paths:
        # pp.pprint("Found tensorflow logs to process:")
        # pp.pprint(event_paths)
        all_logs = many_logs2pandas(event_paths)
        # pp.pprint("Head of created dataframe")
        # pp.pprint(all_logs.head())

        df_data = all_logs.values
        return segment_df(df_data)

# %%
def visualize_logs(all_log_data, env_names, q_types, log_type='imitation_rew', save=False):
    import baselines_plot_utils as pu
    #['Bipedal','Ant', 'Walker2D', 'Hopper', 'HalfCheetah', 'Humanoid']
    for env_n in env_names:

        log_data = all_log_data[env_n]
        min_len = 1e20
        processed_ys = []
        try:
            for i in range(len(log_data)):
                imit_r = log_data[i][log_type]
                #print(np.max(imit_r[:,1].astype(np.int)))
                if True:
                    y = pu.smooth(imit_r[:,1], radius=1)
                    x = imit_r[:,0].astype(np.int)
                    xvals = np.linspace(0, np.max(x), np.max(x))
                    yinterp = np.interp(xvals, x, y)

                    if yinterp.shape[0] < min_len:
                        min_len = yinterp.shape[0]
                    processed_ys.append(yinterp)


            #print(processed_ys)
            for i in range(len(processed_ys)):
                #print(min_len)
                processed_ys[i] = processed_ys[i][:min_len]

                #plt.plot(y)
                #plt.show()

            processed_ys = np.array(processed_ys)
            ys_mean = np.mean(processed_ys, axis=0)
            ys_std = np.std(processed_ys, axis=0)
            plt.plot(ys_mean, label=env_n+' ')
            plt.fill_between(range(min_len), ys_mean+ys_std, ys_mean-ys_std, alpha=0.3)
            plt.legend()
            plt.ylabel(log_type)
            plt.xlabel('steps')
        except:
            print('error parsing records')


        if save:
            plt.savefig(env_n+'_'+'_'+log_type+'.png')
        plt.show()
        

def visualize_logs_compare(log_records, env_names, q_types, log_type='imitation_rew', save=False):
    import baselines_plot_utils as pu
    #['Bipedal','Ant', 'Walker2D', 'Hopper', 'HalfCheetah', 'Humanoid']
    for env_n in env_names:
        for record in log_records:
            log_data = record[env_n]
            min_len = 1e20
            processed_ys = []
            for i in range(len(log_data)):
                imit_r = log_data[i][log_type]
                #print(np.max(imit_r[:,1].astype(np.int)))
                if True:
                    y = pu.smooth(imit_r[:,1], radius=1)
                    x = imit_r[:,0].astype(np.int)
                    xvals = np.linspace(0, np.max(x), np.max(x))
                    yinterp = np.interp(xvals, x, y)

                    if yinterp.shape[0] < min_len:
                        min_len = yinterp.shape[0]
                    processed_ys.append(yinterp)


            #print(processed_ys)
            for i in range(len(processed_ys)):
                #print(min_len)
                processed_ys[i] = processed_ys[i][:min_len]

                #plt.plot(y)
                #plt.show()

            processed_ys = np.array(processed_ys)
            ys_mean = np.mean(processed_ys, axis=0)
            ys_std = np.std(processed_ys, axis=0)
            plt.plot(ys_mean, label=env_n+' ')
            plt.fill_between(range(min_len), ys_mean+ys_std, ys_mean-ys_std, alpha=0.3)
            plt.legend()
            plt.ylabel(log_type)
            plt.xlabel('steps')


        if save:
            plt.savefig(env_n+'_'+'_'+log_type+'.png')
        plt.show()

# %%
env_names = ['Bipedal','Ant', 'Walker2D', 'Hopper', 'HalfCheetah', 'Humanoid']
q_types = ['none', 'upper', 'nstep_lower_upper','nstep_lower', 'DDPGfD']#'nstep_lower_upper', 'DDPGfD']

record_type = 'pwil-optimal_tight_2'#'pwil-mix_ahead_constrained_lower_upper_10steplower—1stepupper_weight03'
log_paths = []
log_dirs = ['../tmp/state_only_True/'+record_type] 
for ld in log_dirs:
    tmp_pths = Path(ld).rglob('*.0')
    log_paths = log_paths + list(tmp_pths)

# %%
    
# prepare dictionary to store all logs
all_log_data = {}


for env_n in env_names:
    all_log_data[env_n]=[]
        
        
# recursively globe all files
for path in log_paths:
    #print(str(path))
    for env_n in env_names:
        if ((env_n in str(path))) and ('222154' not in str(path)) and ('41853' not in str(path)):
            print(path)
            try:
                imitation_rew, real_rew, critic_loss, bc_loss, actor_loss = parse_data_from_boards(str(path))

                imitation_rew = np.array(imitation_rew)[:,1:].astype(np.float)
                real_rew = np.array(real_rew)[:,1:].astype(np.float)
                critic_loss = np.array(critic_loss)[:,1:].astype(np.float)
                bc_loss = np.array(bc_loss)[:,1:].astype(np.float)
                actor_loss = np.array(actor_loss)[:,1:].astype(np.float)

                data_dict = {'imitation_rew': imitation_rew, 'real_rew': real_rew, 'critic_loss': critic_loss, \
                             'bc_loss': bc_loss, 'actor_loss': actor_loss}

                all_log_data[env_n].append(data_dict)
            except:
                print('tensorboard parse error...')
        #print(len(all_log_data[qt][env_n]))
print(all_log_data)
# Out:
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_10/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24104.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_5/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24051.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_1/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24106.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_4/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24083.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_8/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24097.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_6/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24108.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_3/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24067.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_2/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24076.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_7/20210724185058/events.out.tfevents.1627141862.na37.tcsc-local.24060.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/Walker2DBulletEnv-v0_random_9/20210724185058/events.out.tfevents.1627141862.na38.tcsc-local.14001.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_1/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86433.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_6/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86387.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_5/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86414.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_4/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86431.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_9/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86406.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_2/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86424.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_3/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86421.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_10/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86396.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_8/20210724185058/events.out.tfevents.1627141863.na68.tcsc-local.86376.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_9/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222699.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_6/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222741.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_4/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222683.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_5/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222774.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_7/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222714.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_10/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222730.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_10/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222777.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_2/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222690.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_7/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222680.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_2/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222763.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_8/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222765.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_5/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222722.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_3/20210724185058/events.out.tfevents.1627141863.na46.tcsc-local.222707.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_6/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154125.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HopperBulletEnv-v0_random_7/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154169.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_2/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154075.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_2/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154102.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_9/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154166.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_10/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154109.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_3/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154160.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_7/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154137.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_5/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154118.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_1/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154141.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_4/20210724185058/events.out.tfevents.1627141863.na55.tcsc-local.154151.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_6/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234135.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_5/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234123.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_9/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234063.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_4/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234092.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_6/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234041.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_7/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234091.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_8/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234065.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HalfCheetahBulletEnv-v0_random_1/20210724185058/events.out.tfevents.1627141864.na67.tcsc-local.131717.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_1/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234053.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/BipedalWalker-v3_random_8/20210724185058/events.out.tfevents.1627141864.na67.tcsc-local.131724.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_10/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234110.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_3/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234018.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/HumanoidBulletEnv-v0_random_3/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234137.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_8/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234025.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_9/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234033.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_4/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234113.0
# ../tmp/state_only_True/pwil-constrained_optimal_tight_2/constrained_by_wasserstein_constrained_optimal_tight/subsampling_20_numdemo_5/AntBulletEnv-v0_random_1/20210724185058/events.out.tfevents.1627141864.na50.tcsc-local.234073.0
# {'Hopper': [{'critic_loss': array([[1032.        ,  382.19317627],
#        [1066.        ,  300.40185547],
#        [1099.        ,  266.44927979],
#        [1132.        ,  247.77185059],
#        [1164.        ,  291.60076904],
#        [1194.        ,  241.11688232],
#        [1226.        ,  219.39254761],
#        [1257.        ,  257.8737793 ],
#        [1286.        ,  226.0763092 ],
#        [1314.        ,  224.38070679],
#        [1343.        ,  215.61390686],
#        [1371.        ,  223.68362427],
#        [1403.        ,  186.55270386],
#        [1434.        ,  216.62416077],
#        [1465.        ,  197.86117554],
#        [1495.        ,  195.1522522 ],
#        [1526.        ,  210.75183105],
#        [1556.        ,  174.0302887 ],
#        [1586.        ,  201.17739868],
#        [1619.        ,  188.8039093 ],
#        [1648.        ,  201.21972656],
#        [1676.        ,  202.51332092],
#        [1707.        ,  191.16941833],
#        [1736.        ,  175.57382202],
#        [1766.        ,  174.37736511],
#        [1799.        ,  181.2051239 ],
#        [1831.        ,  179.86064148],
#        [1861.        ,  182.1965332 ],
#        [1890.        ,  181.94306946],
#        [1923.        ,  188.67105103],
#        [1955.        ,  154.2278595 ],
#        [1.37100000e+03, 1.06467676e+00],
#        [1.40300000e+03, 1.02148533e+00],
#        [1.43400000e+03, 1.01838732e+00],
#        [1.46500000e+03, 1.06467676e+00],
#        [1.49500000e+03, 1.03199315e+00],
#        [1.52600000e+03, 1.03199315e+00],
#        [1.55600000e+03, 1.03231311e+00],
#        [1.58600000e+03, 1.03231311e+00],
#        [1.61900000e+03, 1.00159311e+00],
#        [1.64800000e+03, 9.89711463e-01],
#        [1.67600000e+03, 1.03199315e+00],
#        [1.70700000e+03, 1.02148533e+00],
#        [1.73600000e+03, 1.00159311e+00],
#        [1.76600000e+03, 1.03199315e+00],
#        [1.79900000e+03, 1.02380538e+00],
#        [1.83100000e+03, 9.89711463e-01],
#        [1.86100000e+03, 1.06467676e+00],
#        [1.89000000e+03, 1.03241193e+00],
#        [1.92300000e+03, 1.03199315e+00],
#        [1.95500000e+03, 1.01838732e+00],
#        [1.98300000e+03, 1.03241193e+00],
#        [2.01300000e+03, 1.01838720e+00],
#        [2.04300000e+03, 1.02373159e+00],
#        [2.08100000e+03, 7.51963556e-01],
#        [2.15500000e+03, 7.40516961e-01],
#        [2.20700000e+03, 3.02194536e-01],
#        [2.24900000e+03, 2.35895351e-01]])}, {'critic_loss': array([[1030.        ,  398.34710693],
#        [1060.        ,  324.62564087],
#        [1093.        ,  296.01971436],
#        [1127.        ,  277.46868896],
#        [1158.        ,  270.4201355 ],
#        [1192.        ,  250.52375793],
#        [1229.        ,  238.46170044],
#        [1263.        ,  225.16014099],
#        [1295.        ,  224.81451416],
#        [1334.        ,  231.96896362],
#        [1374.        ,  231.68173218],
#        [1405.        ,  222.89993286],
#        [1442.        ,  248.36502075],
#        [1473.        ,  169.29804993],
#        [1506.        ,  203.73483276],
#        [1536.        ,  205.80114746],
#        [1575.        ,  191.21250916],
#        [1606.        ,  167.92474365],
#        [1637.        ,  207.05580139],
#        [1674.        ,  194.55316162],
#        [1712.        ,  198.38078308],
#        [1757.        ,  164.9468689 ],
#        [1823.        ,  216.53262329],
#        [1881.        ,  165.19624329],
#        [1916.        ,  198.27320862],
#        [1958.        ,  181.72315979],
#        [2016.        ,  184.93902588],
#        [2073.        ,  157.71360779],
#        [2154.        ,  175.8175354 ]]), 'imitation_rew': array([[1.60000000e+01, 7.31460750e-02],
#        [3.30000000e+01, 1.59886986e-01],
#        [4.30000000e+01, 4.48241830e-01],
#        [5.10000000e+01, 2.43782222e-01],
#        [6.90000000e+01, 1.20085910e-01],
#        [8.80000000e+01, 7.44044423e-01],
#        [9.90000000e+01, 2.47520566e-01],
#        [1.17000000e+02, 2.21815184e-01],
#        [1.28000000e+02, 1.07648242e+00],
#        [1.34000000e+02, 2.44313091e-01],
#        [1.42000000e+02, 1.58627540e-01],
#        [1.49000000e+02, 2.49529734e-01],
#        [1.59000000e+02, 1.63957030e-01],
#        [1.69000000e+02, 3.01612377e-01],
#        [1.77000000e+02, 1.50550887e-01],
#        [1.91000000e+02, 1.15539849e-01],
#        [2.01000000e+02, 5.20789802e-01],
#        [1.22900000e+03, 3.20155650e-01],
#        [1.26300000e+03, 2.23435402e-01],
#        [1.29500000e+03, 3.84302408e-01],
#        [1.33400000e+03, 2.86396354e-01],
#        [1.37400000e+03, 5.54159701e-01],
#        [1.40500000e+03, 5.90955973e-01],
#        [1.44200000e+03, 4.71167445e-01],
#        [1.47300000e+03, 5.58875620e-01],
#        [1.50600000e+03, 5.25108635e-01],
#        [1.53600000e+03, 5.40065527e-01],
#        [1.57500000e+03, 2.72295058e-01],
#        [1.60600000e+03, 3.50724876e-01],
#        [1.63700000e+03, 5.89680493e-01],
#        [1.67400000e+03, 5.20378828e-01],
#        [1.71200000e+03, 6.23529971e-01],
#        [1.75700000e+03, 8.34595978e-01],
#        [1.82300000e+03, 2.35064888e+00],
#        [1.88100000e+03, 6.10395288e+00],
#        [1.91600000e+03, 7.49324799e+00],
#        [1.95800000e+03, 5.97653341e+00],
#        [2.01600000e+03, 7.54926062e+00],
#        [2.07300000e+03, 3.47309566e+00],
#        [2.15400000e+03, 4.18940210e+00]]), 'actor_loss': array([[1030.        ,   -9.27375412],
#        [1060.        ,  -10.51363373],
#        [1093.        ,   -9.23160553],
#        [1127.        ,  -10.77332973],
#        [1158.        ,  -13.89949703],
#        [1192.        ,  -12.80080891],
#        [1229.        ,  -14.0073576 ],
#        [1263.        ,  -16.22737312],
#        [1295.        ,  -20.92100906],
#        [1334.        ,  -23.39211655],
#        [1374.        ,  -23.17942619],
#        [1405.        ,  -24.30882263],
#        [1442.        ,  -27.0810318 ],
#        [1473.        ,  -23.17994118],
#        [1506.        ,  -26.22147369],
#        [1536.        ,  -25.34651184],
#        [1575.        ,  -27.33437729],
#        [1606.        ,  -27.43805122],
#        [1637.        ,  -29.86541557],
#        [1674.        ,  -28.03099632],
#        [1712.        ,  -32.414711  ],
#        [1757.        ,  -30.16945648],
#        [1823.        ,  -35.04885101],
#        [1881.        ,  -31.39651871],
#        [1916.        ,  -33.74929428],
#        [1958.        ,  -35.52299881],
#        [2016.        ,  -37.80245972],
#        [2073.        ,  -36.56917572],
#        [2154.        ,  -38.61886215]]), 'real_rew': array([[6.00000000e+00, 1.64302616e+01],
#        [1.60000000e+01, 1.63507767e+01],
#        [3.30000000e+01, 2.05897598e+01],
#        [4.30000000e+01, 1.75917301e+01],
#        [5.10000000e+01, 1.42634258e+01],
#        [6.90000000e+01, 2.10599194e+01],
#        [8.80000000e+01, 1.60964642e+01],
#        [9.90000000e+01, 1.55157185e+01],
#        [1.17000000e+02, 2.64872227e+01],
#        [1.28000000e+02, 2.16183414e+01],
#        [1.34000000e+02, 1.94571972e+01],
#        [1.42000000e+02, 1.86313457e+01],
#        [1.49000000e+02, 2.21402187e+01],
#        [1.59000000e+02, 2.20930138e+01],
#        [1.69000000e+02, 2.08261337e+01],
#        [1.77000000e+02, 2.02871227e+01],
#        [1.91000000e+02, 2.81177349e+01],
#        [2.01000000e+02, 2.38546524e+01],
#        [2.11000000e+02, 2.02460308e+01],
#        [2.26000000e+02, 2.48267822e+01],
#        [1.29500000e+03, 9.24797821e+00],
#        [1.33400000e+03, 2.10389881e+01],
#        [1.37400000e+03, 3.18897820e+01],
#        [1.40500000e+03, 8.95030117e+00],
#        [1.44200000e+03, 2.31814880e+01],
#        [1.47300000e+03, 1.11493645e+01],
#        [1.50600000e+03, 7.81452990e+00],
#        [1.53600000e+03, 5.60686493e+00],
#        [1.57500000e+03, 3.21438026e+01],
#        [1.60600000e+03, 7.75066519e+00],
#        [1.63700000e+03, 1.91348398e+00],
#        [1.67400000e+03, 3.42111092e+01],
#        [1.71200000e+03, 3.25435104e+01],
#        [1.75700000e+03, 3.26027718e+01],
#        [1.82300000e+03, 4.60739784e+01],
#        [1.88100000e+03, 4.89121437e+01],
#        [1.91600000e+03, 3.56168861e+01],
#        [1.95800000e+03, 5.13295097e+01],
#        [2.01600000e+03, 5.21353569e+01],
#        [2.07300000e+03, 5.48236313e+01],
#        [2.15400000e+03, 8.77990952e+01]]), 'bc_loss': array([[1.03000000e+03, 1.01868331e+00],
#        [1.06000000e+03, 9.81399596e-01],
#        [1.09300000e+03, 9.42635775e-01],
#        [1.12700000e+03, 9.82892752e-01],
#        [1.15800000e+03, 9.69384432e-01],
#        [1.19200000e+03, 9.68998015e-01],
#        [1.22900000e+03, 1.01868868e+00],
#        [1.26300000e+03, 9.69383895e-01],
#        [1.29500000e+03, 6.73381090e-01],
#        [1.33400000e+03, 6.20625675e-01],
#        [1.37400000e+03, 6.05032861e-01],
#        [1.40500000e+03, 5.59737623e-01],
#        [1.44200000e+03, 5.59946358e-01],
#        [1.47300000e+03, 5.52529752e-01],
#        [1.50600000e+03, 5.33538640e-01],
#        [1.53600000e+03, 5.17280400e-01],
#        [1.57500000e+03, 5.49756348e-01],
#        [1.60600000e+03, 5.48044443e-01],
#        [1.63700000e+03, 4.94242996e-01],
#        [1.67400000e+03, 4.18782443e-01],
#        [1.71200000e+03, 4.41376388e-01],
#        [1.75700000e+03, 3.50936651e-01],
#        [1.82300000e+03, 3.17102164e-01],
#        [1.88100000e+03, 3.07010084e-01],
#        [1.91600000e+03, 3.00453693e-01],
#        [1.95800000e+03, 3.01023632e-01],
#        [2.01600000e+03, 2.68630624e-01],
#        [2.07300000e+03, 2.97954053e-01],
#        [2.15400000e+03, 2.90045410e-01]])}, {'critic_loss': array([[1023.        ,  424.91275024],
#        [1056.        ,  284.60684204],
#        [1088.        ,  263.64233398],
#        [1120.        ,  252.12957764],
#        [1149.        ,  226.7383728 ],
#        [1180.        ,  247.01275635],
#        [1214.        ,  229.90818787],
#        [1247.        ,  224.52145386],
#        [1276.        ,  227.73336792],
#        [1310.        ,  223.80395508],
#        [1341.        ,  219.52172852],
#        [1374.        ,  215.44949341],
#        [1407.        ,  242.22454834],
#        [1440.        ,  211.92759705],
#        [1473.        ,  223.81207275],
#        [1507.        ,  214.28839111],
#        [1540.        ,  203.72286987],
#        [1572.        ,  188.05570984],
#        [1605.        ,  164.48162842],
#        [1640.        ,  216.84732056],
#        [1676.        ,  188.90348816],
#        [7.95000000e+02, 1.18124194e-01],
#        [8.15000000e+02, 1.75929219e-01],
#        [8.25000000e+02, 3.92077774e-01],
#        [8.50000000e+02, 8.69446099e-02],
#        [8.65000000e+02, 2.86203086e-01],
#        [8.79000000e+02, 3.28958899e-01],
#        [9.09000000e+02, 4.50616509e-01],
#        [9.22000000e+02, 6.10161364e-01],
#        [9.33000000e+02, 4.54158664e-01],
#        [9.46000000e+02, 1.77607551e-01],
#        [9.54000000e+02, 3.37151408e-01],
#        [9.68000000e+02, 2.29094878e-01],
#        [9.79000000e+02, 3.49161297e-01],
#        [1.02300000e+03, 2.87034601e-01],
#        [1.05600000e+03, 1.01778758e+00],
#        [1.08800000e+03, 3.69094074e-01],
#        [1.12000000e+03, 1.66510835e-01],
#        [1.14900000e+03, 2.60193914e-01],
#        [1.18000000e+03, 2.22893581e-01],
#        [1.21400000e+03, 2.76324660e-01],
#        [1.24700000e+03, 3.56884420e-01],
#        [1.27600000e+03, 3.16166013e-01],
#        [1.31000000e+03, 1.88010707e-01],
#        [1.34100000e+03, 3.71855825e-01],
#        [1.37400000e+03, 3.32575709e-01],
#        [1.40700000e+03, 3.15941960e-01],
#        [1.44000000e+03, 2.70774126e-01],
#        [1.47300000e+03, 3.43871832e-01],
#        [1.50700000e+03, 3.52439940e-01],
#        [1.54000000e+03, 2.78741539e-01],
#        [1.57200000e+03, 3.55002940e-01],
#        [1.60500000e+03, 3.33281636e-01],
#        [1.64000000e+03, 1.54842481e-01],
#        [1.67600000e+03, 2.97230065e-01],
#        [1.71300000e+03, 5.21209955e-01],
#        [1.75000000e+03, 6.04229867e-01],
#        [1.82000000e+03, 2.73821473e+00],
#        [1.87800000e+03, 2.00321541e+01],
#        [1.92700000e+03, 4.05304050e+00],
#        [1.98200000e+03, 3.54330850e+00],
#        [2.03300000e+03, 9.28033257e+00],
#        [2.10200000e+03, 3.58762240e+00],
#        [2.18500000e+03, 2.83112025e+00],
#        [2.38200000e+03, 1.05685549e+01],
#        [2.43700000e+03, 1.02040415e+01]]), 'actor_loss': array([[1023.        ,   -8.96285629],
#        [1056.        ,  -11.50918961],
#        [1088.        ,  -10.36280727],
#        [1120.        ,  -10.39067841],
#        [1149.        ,  -11.054739  ],
#        [1180.        ,  -13.67838669],
#        [1214.        ,  -17.86508369],
#        [1247.        ,  -16.29992485],
#        [1276.        ,  -17.42926216],
#        [1310.        ,  -19.36214447],
#        [1341.        ,  -19.56503105],
#        [1374.        ,  -20.53473854],
#        [1407.        ,  -21.15437698],
#        [1440.        ,  -21.88984108],
#        [1473.        ,  -21.83055878],
#        [1507.        ,  -22.96917152],
#        [1540.        ,  -22.62947845],
#        [1572.        ,  -24.18689919],
#        [1605.        ,  -24.19831467],
#        [1640.        ,  -27.71221924],
#        [1676.        ,  -28.30042458],
#        [1713.        ,  -28.9930706 ],
#        [1750.        ,  -32.18148041],
#        [1820.        ,  -34.23070145],
#        [1878.        ,  -34.00227356],
#        [1927.        ,  -37.95814896],
#        [1982.        ,  -36.24180984],
#        [2033.        ,  -35.34033585],
#        [2102.        ,  -37.64614868],
#        [2185.        ,  -37.2947731 ],
#        [2382.        ,  -46.11838913],
#        [2437.        ,  -47.76499176]]), 'real_rew': array([[   6.        ,   18.17300415],
#        [  12.        ,   17.25188255],
#        [  20.        ,   19.9693203 ],
#        [  33.        ,   15.31744003],
#        [  40.        ,   17.77981186],
#        [  46.        ,   16.77006912],
#        [  61.        ,   21.19433594],
#        [  74.        ,   16.30362511],
#        [  88.        ,   14.4807024 ],
#        [  97.        ,   20.69211769],
#        [ 111.        ,   23.47214699],
#        [ 131.        ,   16.68466949],
#        [ 143.        ,   22.87777138],
#        [ 157.        ,   20.02095604],
#        [ 169.        ,   19.58901596],
#        [ 179.        ,   20.31562042],
#        [ 188.        ,   23.07415581],
#        [ 202.        ,   23.38230324],
#        [ 214.        ,   22.56834984],
#        [ 232.        ,   22.57795334],
#        [ 243.        ,   23.05877876],
#        [ 252.        ,   20.29196739],
#        [ 270.        ,   24.1528492 ],
#        [ 286.        ,   25.61050415],
#        [ 308.        ,   29.04344177],
#        [ 324.        ,   26.65865135],
#        [ 346.        ,   29.88902473],
#        [ 358.        ,   23.00805664],
#        [ 380.        ,   25.88828087],
#        [ 386.        ,   17.59014702],
#        [ 396.        ,   18.85434151],
#        [ 409.        ,   24.98355865],
#        [ 423.        ,   19.90728569],
#        [ 441.        ,   27.34051895],
#        [ 454.        ,   21.26609802],
#        [ 464.        ,   18.47536087],
#        [ 474.        ,   20.73210526],
#        [ 482.        ,   20.79191589],
#        [ 506.        ,   30.76311684],
# ...
#        [1.22800000e+03, 8.98118973e-01],
#        [1.24400000e+03, 8.75616133e-01],
#        [1.26100000e+03, 8.76105905e-01],
#        [1.27800000e+03, 8.68867278e-01],
#        [1.29500000e+03, 8.68924081e-01],
#        [1.31200000e+03, 8.68909836e-01],
#        [1.32900000e+03, 8.90982509e-01],
#        [1.35200000e+03, 8.53672683e-01],
#        [1.36900000e+03, 8.74276459e-01],
#        [1.38600000e+03, 8.66134167e-01],
#        [1.41400000e+03, 8.61158788e-01],
#        [1.44600000e+03, 8.26765537e-01],
#        [1.48200000e+03, 7.80272007e-01],
#        [1.50300000e+03, 9.05803978e-01],
#        [1.52100000e+03, 1.13627505e+00],
#        [1.54600000e+03, 1.25366497e+00],
#        [1.56600000e+03, 1.24076366e+00],
#        [1.58500000e+03, 1.15083778e+00],
#        [1.60800000e+03, 1.08727610e+00],
#        [1.62700000e+03, 1.06322432e+00],
#        [1.65200000e+03, 1.17250276e+00],
#        [1.67400000e+03, 1.15701151e+00],
#        [1.69400000e+03, 1.06286561e+00],
#        [1.71400000e+03, 1.05256939e+00],
#        [1.73900000e+03, 1.02723897e+00],
#        [1.75800000e+03, 1.00977945e+00],
#        [1.78000000e+03, 9.63660300e-01],
#        [1.80700000e+03, 9.74213779e-01],
#        [1.82400000e+03, 9.57354128e-01],
#        [1.84800000e+03, 1.05374396e+00],
#        [1.86900000e+03, 1.05117691e+00],
#        [1.89100000e+03, 9.41160083e-01],
#        [1.91400000e+03, 8.60153079e-01],
#        [1.94300000e+03, 8.19528759e-01],
#        [1.96200000e+03, 7.62534857e-01],
#        [1.98500000e+03, 7.40857780e-01],
#        [2.00600000e+03, 7.12075472e-01],
#        [2.02500000e+03, 7.49530315e-01],
#        [2.04900000e+03, 7.83813715e-01]])}, {'critic_loss': array([[1003.        ,   41.18027878],
#        [1019.        ,   26.5530777 ],
#        [1036.        ,   21.5028801 ],
#        [1048.        ,   26.41365051],
#        [1065.        ,   18.20958328],
#        [1082.        ,   22.60790634],
#        [1094.        ,   19.59742165],
#        [1111.        ,   22.28667259],
#        [1129.        ,   25.56277466],
#        [1146.        ,   22.77797508],
#        [1157.        ,   21.51981735],
#        [1174.        ,   18.02812958],
#        [1191.        ,   21.85189438],
#        [1208.        ,   24.10208321],
#        [1226.        ,   23.31484222],
#        [1243.        ,   25.49572563],
#        [1261.        ,   18.31207275],
#        [1280.        ,   20.78489494],
#        [1299.        ,   16.05054092],
#        [1327.        ,   20.49623489],
#        [1359.        ,   19.03141785],
#        [1386.        ,   21.16389465],
#        [1413.        ,   19.9631691 ],
#        [1439.        ,   11.74317169],
#        [1467.        ,   17.82229424],
#        [1487.        ,   18.6727562 ],
#        [1509.        ,   18.19962883],
#        [1535.        ,   14.66360283],
#        [1561.        ,   17.91889   ],
#        [1587.        ,   23.88122177],
#        [1612.        ,   20.17504311],
#        [1639.        ,   16.31902313],
#        [1664.        ,   15.61050034],
#        [1690.        ,   23.48731041],
#        [1713.        ,   16.22782516],
#        [1735.        ,   16.61190414],
#        [1753.        ,   15.66453266],
#        [1780.        ,   17.8077507 ],
#        [1808.        ,   15.14166641],
#        [1826.        ,   15.7448349 ],
#        [1843.        ,   14.65384865],
#        [1859.        ,   19.5929985 ],
#        [1876.        ,   16.10561752],
#        [1893.        ,   10.96511173],
#        [1911.        ,   12.86400509],
#        [1931.        ,   11.82370949],
#        [1949.        ,   12.33252144],
#        [1970.        ,   15.33360481],
#        [1990.        ,   10.1616497 ]]), 'imitation_rew': array([[3.90000000e+01, 2.45596621e-05],
#        [5.80000000e+01, 2.28461158e-05],
#        [7.70000000e+01, 7.13298869e-05],
#        [9.60000000e+01, 3.35440782e-05],
#        [1.15000000e+02, 2.97161041e-05],
#        [1.35000000e+02, 1.91530835e-05],
#        [1.55000000e+02, 1.53209658e-05],
#        [1.76000000e+02, 7.41709300e-05],
#        [1.93000000e+02, 9.93122303e-05],
#        [2.13000000e+02, 4.99742964e-05],
#        [2.32000000e+02, 7.28861633e-05],
#        [2.51000000e+02, 1.68416154e-05],
#        [2.70000000e+02, 2.38191733e-05],
#        [2.89000000e+02, 9.35652351e-05],
#        [3.08000000e+02, 3.34473880e-05],
#        [3.26000000e+02, 2.49642879e-04],
#        [3.45000000e+02, 3.09171446e-05],
#        [3.67000000e+02, 2.03123811e-04],
#        [3.87000000e+02, 7.55301662e-05],
#        [4.07000000e+02, 2.40411737e-05],
#        [4.27000000e+02, 6.71751695e-05],
#        [4.46000000e+02, 7.79357870e-05],
#        [4.65000000e+02, 4.18959462e-05],
#        [4.83000000e+02, 1.63032993e-04],
#        [5.04000000e+02, 2.67002360e-05],
#        [5.22000000e+02, 3.34690558e-04],
#        [5.41000000e+02, 2.79268770e-05],
#        [5.64000000e+02, 3.61983948e-05],
#        [5.83000000e+02, 8.17718901e-05],
#        [6.02000000e+02, 3.10445539e-05],
#        [6.21000000e+02, 4.85463606e-05],
#        [6.42000000e+02, 1.97986574e-05],
#        [6.61000000e+02, 1.60148164e-04],
#        [6.80000000e+02, 4.33375426e-05],
#        [7.05000000e+02, 6.50410875e-05],
#        [7.26000000e+02, 3.92563787e-04],
#        [7.45000000e+02, 9.69302928e-05],
#        [7.64000000e+02, 8.96619313e-05],
#        [7.88000000e+02, 2.41139096e-05],
#        [8.07000000e+02, 2.85421003e-04],
#        [8.26000000e+02, 2.98881077e-05],
#        [8.46000000e+02, 8.01003844e-05],
#        [8.64000000e+02, 2.94925921e-05],
#        [8.82000000e+02, 3.97305848e-05],
#        [9.02000000e+02, 1.90134342e-05],
#        [9.21000000e+02, 5.37174128e-05],
#        [9.39000000e+02, 2.29399648e-05],
#        [9.62000000e+02, 2.36462583e-05],
#        [9.83000000e+02, 3.27216694e-05],
#        [1.00300000e+03, 5.98998668e-05],
#        [1.01900000e+03, 2.65145500e-05],
#        [1.03600000e+03, 3.95754614e-05],
#        [1.04800000e+03, 2.65385952e-05],
#        [1.06500000e+03, 5.11329272e-05],
#        [1.08200000e+03, 6.99738230e-05],
#        [1.09400000e+03, 2.46071195e-05],
#        [1.11100000e+03, 6.13351731e-05],
#        [1.12900000e+03, 6.68390494e-05],
#        [1.14600000e+03, 2.11498409e-05],
#        [1.15700000e+03, 5.59971268e-05],
#        [1.17400000e+03, 1.31748711e-05],
#        [1.19100000e+03, 2.45788087e-05],
#        [1.20800000e+03, 3.20533291e-05],
#        [1.22600000e+03, 1.46078992e-05],
#        [1.24300000e+03, 5.33612438e-05],
#        [1.26100000e+03, 2.82548135e-05],
#        [1.28000000e+03, 4.59846779e-05],
#        [1.29900000e+03, 7.66566882e-05],
#        [1.32700000e+03, 7.43702476e-05],
#        [1.35900000e+03, 5.44818940e-05],
#        [1.38600000e+03, 1.57327540e-05],
#        [1.41300000e+03, 5.32587692e-05],
#        [1.43900000e+03, 6.56548873e-05],
#        [1.46700000e+03, 4.77166213e-05],
#        [1.48700000e+03, 1.30562312e-05],
#        [1.50900000e+03, 6.56472475e-05],
#        [1.53500000e+03, 6.12442891e-05],
#        [1.56100000e+03, 5.10227692e-05],
#        [1.58700000e+03, 5.41095251e-05],
#        [1.61200000e+03, 3.30765652e-05],
#        [1.63900000e+03, 1.86770430e-05],
#        [1.66400000e+03, 2.14929896e-05],
#        [1.69000000e+03, 3.35158911e-05],
#        [1.71300000e+03, 3.56576566e-05],
#        [1.73500000e+03, 6.40424041e-05],
#        [1.75300000e+03, 8.19558045e-05],
#        [1.78000000e+03, 1.55290763e-05],
#        [1.80800000e+03, 3.15710386e-05],
#        [1.82600000e+03, 4.98220106e-05],
#        [1.84300000e+03, 4.83197473e-05],
#        [1.85900000e+03, 2.36218148e-05],
#        [1.87600000e+03, 2.51061520e-05],
#        [1.89300000e+03, 5.64916045e-05],
#        [1.91100000e+03, 7.49025858e-05],
#        [1.93100000e+03, 7.55185756e-05],
#        [1.94900000e+03, 2.51434940e-05],
#        [1.97000000e+03, 1.17892530e-04],
#        [1.99000000e+03, 3.52354582e-05]]), 'actor_loss': array([[ 1.00300000e+03, -5.64392507e-01],
#        [ 1.01900000e+03, -2.47458124e+00],
#        [ 1.03600000e+03, -1.79012609e+00],
#        [ 1.04800000e+03, -1.74563885e+00],
#        [ 1.06500000e+03, -2.51865745e+00],
#        [ 1.08200000e+03, -2.53431225e+00],
#        [ 1.09400000e+03, -2.41397190e+00],
#        [ 1.11100000e+03, -1.90122151e+00],
#        [ 1.12900000e+03, -2.13411427e+00],
#        [ 1.14600000e+03, -3.01698995e+00],
#        [ 1.15700000e+03, -2.26147318e+00],
#        [ 1.17400000e+03, -2.57164288e+00],
#        [ 1.19100000e+03, -2.56099939e+00],
#        [ 1.20800000e+03, -2.45955181e+00],
#        [ 1.22600000e+03, -2.51427579e+00],
#        [ 1.24300000e+03, -2.09699607e+00],
#        [ 1.26100000e+03, -2.21634007e+00],
#        [ 1.28000000e+03, -4.09582233e+00],
#        [ 1.29900000e+03, -5.49453592e+00],
#        [ 1.32700000e+03, -6.58395958e+00],
#        [ 1.35900000e+03, -6.95513773e+00],
#        [ 1.38600000e+03, -7.16128111e+00],
#        [ 1.41300000e+03, -8.44269085e+00],
#        [ 1.43900000e+03, -7.41680050e+00],
#        [ 1.46700000e+03, -7.34235954e+00],
#        [ 1.48700000e+03, -6.99024153e+00],
#        [ 1.50900000e+03, -8.18329334e+00],
#        [ 1.53500000e+03, -9.24727249e+00],
#        [ 1.56100000e+03, -8.39271259e+00],
#        [ 1.58700000e+03, -8.83783245e+00],
#        [ 1.61200000e+03, -9.53049755e+00],
#        [ 1.63900000e+03, -7.90415096e+00],
#        [ 1.66400000e+03, -7.59643555e+00],
#        [ 1.69000000e+03, -8.42776012e+00],
#        [ 1.71300000e+03, -8.38318825e+00],
#        [ 1.73500000e+03, -8.79962349e+00],
#        [ 1.75300000e+03, -8.17441368e+00],
#        [ 1.78000000e+03, -8.39358616e+00],
#        [ 1.80800000e+03, -1.09028101e+01],
#        [ 1.82600000e+03, -1.16592703e+01],
#        [ 1.84300000e+03, -1.08740425e+01],
#        [ 1.85900000e+03, -1.34123926e+01],
#        [ 1.87600000e+03, -1.41536989e+01],
#        [ 1.89300000e+03, -1.35975199e+01],
#        [ 1.91100000e+03, -1.21643162e+01],
#        [ 1.93100000e+03, -1.43668337e+01],
#        [ 1.94900000e+03, -1.43601074e+01],
#        [ 1.97000000e+03, -1.51605110e+01],
#        [ 1.99000000e+03, -1.34938135e+01]]), 'real_rew': array([[ 1.90000000e+01, -4.82988663e+01],
#        [ 3.90000000e+01, -6.28883629e+01],
#        [ 1.20800000e+03, -6.12259178e+01],
#        [ 1.22600000e+03, -5.22318459e+01],
#        [ 1.24300000e+03, -5.63384743e+01],
#        [ 1.26100000e+03, -5.78044052e+01],
#        [ 1.28000000e+03, -6.39443359e+01],
#        [ 1.29900000e+03, -6.14044952e+01],
#        [ 1.32700000e+03, -3.83734665e+01],
#        [ 1.35900000e+03, -4.03457489e+01],
#        [ 1.38600000e+03, -4.73587379e+01],
#        [ 1.41300000e+03, -4.00617790e+01],
#        [ 1.43900000e+03, -3.27586899e+01],
#        [ 1.46700000e+03, -3.18443680e+01],
#        [ 1.48700000e+03, -5.61497841e+01],
#        [ 1.50900000e+03, -4.72113762e+01],
#        [ 1.53500000e+03, -4.93745995e+01],
#        [ 1.56100000e+03, -4.05412636e+01],
#        [ 1.58700000e+03, -4.57827911e+01],
#        [ 1.61200000e+03, -3.08428249e+01],
#        [ 1.63900000e+03, -4.03538399e+01],
#        [ 1.66400000e+03, -4.22007217e+01],
#        [ 1.69000000e+03, -4.49330826e+01],
#        [ 1.71300000e+03, -4.69025269e+01],
#        [ 1.73500000e+03, -5.64344482e+01],
#        [ 1.75300000e+03, -5.16912193e+01],
#        [ 1.78000000e+03, -5.03000298e+01],
#        [ 1.80800000e+03, -4.61536407e+01],
#        [ 1.82600000e+03, -3.65133247e+01],
#        [ 1.84300000e+03, -3.92611389e+01],
#        [ 1.85900000e+03, -4.42768936e+01],
#        [ 1.87600000e+03, -5.62661438e+01],
#        [ 1.89300000e+03, -4.79054756e+01],
#        [ 1.91100000e+03, -4.84637871e+01],
#        [ 1.93100000e+03, -5.12624817e+01],
#        [ 1.94900000e+03, -4.13950424e+01],
#        [ 1.97000000e+03, -3.94724274e+01],
#        [ 1.99000000e+03, -4.83467712e+01]]), 'bc_loss': array([[1.00300000e+03, 3.47906888e-01],
#        [1.01900000e+03, 1.25947881e+00],
#        [1.03600000e+03, 1.24417901e+00],
#        [1.04800000e+03, 1.27485371e+00],
#        [1.06500000e+03, 1.26027453e+00],
#        [1.08200000e+03, 1.25298786e+00],
#        [1.09400000e+03, 1.26205754e+00],
#        [1.11100000e+03, 1.24417949e+00],
#        [1.12900000e+03, 1.27485371e+00],
#        [1.14600000e+03, 1.26792753e+00],
#        [1.15700000e+03, 1.26792753e+00],
#        [1.17400000e+03, 1.25298786e+00],
#        [1.19100000e+03, 1.26205778e+00],
#        [1.20800000e+03, 1.25298798e+00],
#        [1.22600000e+03, 1.28300297e+00],
#        [1.24300000e+03, 1.24412322e+00],
#        [1.26100000e+03, 1.24334812e+00],
#        [1.28000000e+03, 1.28516805e+00],
#        [1.29900000e+03, 1.15245104e+00],
#        [1.32700000e+03, 1.15996599e+00],
#        [1.35900000e+03, 1.15996599e+00],
#        [1.38600000e+03, 1.15250564e+00],
#        [1.41300000e+03, 1.15103972e+00],
#        [1.43900000e+03, 1.15996599e+00],
#        [1.46700000e+03, 1.16097474e+00],
#        [1.48700000e+03, 1.15250564e+00],
#        [1.50900000e+03, 1.16888976e+00],
#        [1.53500000e+03, 1.16026354e+00],
#        [1.56100000e+03, 1.15996599e+00],
#        [1.58700000e+03, 1.15996599e+00],
#        [1.61200000e+03, 1.15250564e+00],
#        [1.63900000e+03, 1.15611982e+00],
#        [1.66400000e+03, 1.15103972e+00],
#        [1.69000000e+03, 1.16097474e+00],
#        [1.71300000e+03, 1.19737136e+00],
#        [1.73500000e+03, 1.20927477e+00],
#        [1.75300000e+03, 1.21407187e+00],
#        [1.78000000e+03, 1.16784739e+00],
#        [1.80800000e+03, 1.06944382e+00],
#        [1.82600000e+03, 8.42828274e-01],
#        [1.84300000e+03, 9.25298452e-01],
#        [1.85900000e+03, 9.57607031e-01],
#        [1.87600000e+03, 1.02954435e+00],
#        [1.89300000e+03, 9.93546009e-01],
#        [1.91100000e+03, 9.71588671e-01],
#        [1.93100000e+03, 9.75866854e-01],
#        [1.94900000e+03, 9.49025333e-01],
#        [1.97000000e+03, 8.87335718e-01],
#        [1.99000000e+03, 9.83176172e-01]])}]}

# %%
with open(record_type+'.pkl', 'wb') as handle:
    pickle.dump(all_log_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(record_type+'.pkl', 'rb') as handle:
    all_log_data = pickle.load(handle)

# %%
visualize_logs(all_log_data, env_names, [q_types[0],q_types[1],q_types[2],q_types[3], q_types[4]], log_type='imitation_rew', save=False)
# Out:
# error parsing records
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
visualize_logs(all_log_data, env_names, [q_types[0],q_types[1],q_types[2],q_types[3]], log_type='bc_loss', save=True)

visualize_logs(all_log_data, env_names, [q_types[0],q_types[1]], log_type='bc_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[2]], log_type='bc_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[3]], log_type='bc_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[4]], log_type='bc_loss', save=True)
# Out:
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
visualize_logs(all_log_data, env_names, q_types[:4], log_type='critic_loss', save=True)

visualize_logs(all_log_data, env_names, [q_types[0],q_types[1]], log_type='critic_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[2]], log_type='critic_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[3]], log_type='critic_loss', save=True)
visualize_logs(all_log_data, env_names, [q_types[0],q_types[4]], log_type='critic_loss', save=True)
# Out:
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/wenyan/.local/lib/python3.5/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
